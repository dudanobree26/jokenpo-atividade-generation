# %% [markdown]
# <a href="https://colab.research.google.com/github/dudanobree26/jokenpo-atividade-generation/blob/main/jo_ken_po(codigo).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#definir as variaveis
jogador1 = input("informme o nome do jpgador 1")
jogador2 = input('informe o nome do jogador 2')

pontuação1 = 0
pontuação1 = 0

movimento1 = ''
movimento2 =''

# %%
def escolhar_jogada():
#função
  print('='*20)
  print('as jogadas que temos são:')
  print('pedra')
  print('papel')
  print('tesoura')
  print('='*20)
  print('digite o texto da opção')

  movimento1 = input(f'{jogador1}, informe sua jogada').lower()
  movimento2 = input(f'{jogador2}, informe sua jogada').lower()

  return movimento1, movimento2

def jogar():
   print(f'{jogador1} escolheu {movimento1}')
   print(f'{jogador2} escolheu {movimento2}')

   if movimento1 == "pedra" and movimento2 == 'papel':
    print(f"{jogador2} ganhou!")
    pontuação2 += 1
   elif movimento1 == 'pedra' and movimento2 == 'tesoura':
    print(f'{jogador1} ganhou!')
    pontuação1 += 1
   elif movimento1 == 'papel' and movimento2 == 'tesoura':
    print(f'{jogador2} ganhou!')
    pontuação2 += 1
   elif movimento1 == 'tesoura' and movimento2 == 'pedra':
    print(f'{jogador2} ganhou!')
    pontuação2 += 1
   elif movimento1== 'tesoura' and movimento2 == 'papel':
    print(f'{jogador1} ganhou!')
    pontuação1 += 1
   elif movimento1 == 'pedra' and movimento2 == 'tesoura':
    print(f'{jogador1} ganhou!')
    pontuação1 += 1
   else:
    print('empatou')

   def regras();
    print('pedra ganha de tesoura')
    print('papel ganha de pedra')
    print('tesoura ganha de papel')

# %%
print('vamos iniciar o jogo?')
print('1 - regras')
print('2 - jogar')
escolha = input('qual opção desejda? 1 ou 2')

if escolha == "1":
  regras()
elif escolha == "2":
  movimento1, movimento2 = escolher_jogada()
  jogar()
else:
  print('opção nao encontrada')
